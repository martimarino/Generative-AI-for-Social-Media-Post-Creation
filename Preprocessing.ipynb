# %%
# Python program to convert .tsv file to .csv file
# importing re library
import re

# reading given tsv file
with open("drive/MyDrive/BPM/dataset.tsv", 'r') as myfile:
  with open("drive/MyDrive/BPM/dataset.csv", 'w') as csv_file:
    for line in myfile:
    
    # Replace every tab with comma
      fileContent = re.sub("\t", ",", line)
    
    # Writing into csv file
      csv_file.write(fileContent)

# output
print("Successfully made csv file")
# Out:
# Successfully made csv file

# %%
import csv
import os
#os.chdir("drive/MyDrive/BPM")
print(os.getcwd())
with open('dataset.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
      if line_count == 0:
          print(f'Column names are {", ".join(row)}')
          line_count += 1
      else:
          #print(row[3], row[13], row[14], row[15], row[21], row[24])
          line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# /content/drive/MyDrive/BPM
# Column names are Uniq Id, Crawl Timestamp, Dataset Origin, Product Id, Product Barcode, Product Company Type Source, Product Brand Source, Product Brand Normalised Source, Product Name Source, Match Rank, Match Score, Match Type, Retailer, Product Category, Product Brand, Product Name, Product Price, Sku, Upc, Product Url, Market, Product Description, Product Currency, Product Available Inventory, Product Image Url, Product Model Number, Product Tags, Product Contents, Product Rating, Product Reviews Count, Bsr, Joining Key
# Processed 29985 lines.

# %%
import csv
import os

id = []
category = []
brand = []
name = [] 
description = []
img = [] 

with open('dataset.csv', 'r') as csv_file:
  csv_reader = csv.reader(csv_file, delimiter=',')
  line_count = 0
  for row in csv_reader:
    if line_count == 0:
      print(f'Column names are {", ".join(row)}')
      line_count += 1
    else:
      #print(row[3], row[13], row[14], row[15], row[21], row[24])
      id.append(row[3])
      category.append(row[13])
      brand.append(row[14])
      name.append(row[15])
      description.append(row[21])
      img.append(row[24])
      line_count += 1
  print(f'Processed {line_count} lines.')


print(brand)
# Out:
# Column names are Uniq Id, Crawl Timestamp, Dataset Origin, Product Id, Product Barcode, Product Company Type Source, Product Brand Source, Product Brand Normalised Source, Product Name Source, Match Rank, Match Score, Match Type, Retailer, Product Category, Product Brand, Product Name, Product Price, Sku, Upc, Product Url, Market, Product Description, Product Currency, Product Available Inventory, Product Image Url, Product Model Number, Product Tags, Product Contents, Product Rating, Product Reviews Count, Bsr, Joining Key
# Processed 29985 lines.
# ...

# %%
header = ['id', 'category', 'brand', 'name', 'description', 'img']
with open('filtered.csv', 'w') as write_file: 
  writer = csv.writer(write_file)

  # write the header
  writer.writerow(header)

  for i in range(len(id)): 
    row = []
    row.append(id[i])
    row.append(category[i])
    row.append(brand[i])
    row.append(name[i])
    row.append(description[i])
    row.append(img[i])
    # write the data
    writer.writerow(row)

# %%
import csv
import os

with open('filtered.csv', 'r') as csv_file:
  csv_reader = csv.reader(csv_file, delimiter=',')
  line_count = 0
  for row in csv_reader:
    if line_count == 0:
      print(f'Column names are {", ".join(row)}')
      line_count += 1
    else:
      print(row)
      line_count += 1
  print(f'Processed {line_count} lines.')
# Out:
# Column names are id, category, brand, name, description, img
# ['ed177532df52b8b2fdba6cff731b9d00', 'Home & Kitchen > Kitchen & Dining > Kitchen & Table Linens > Table Runners', 'Ramanta Home', '100% Linen Table Runner 14x90 Tailored with Mitered Corner & Hand Crafted with Hemstitch detailing - Natural (1Pack)', '', '100% Linen Table Runner 14x90 Tailored with Mitered Corner & Hand Crafted with Hemstitch detailing - Natural (1Pack)']
# ['8756f065784790599a218174bc932395', 'Beauty & Personal Care > Personal Care > Bath & Bathing Accessories > Bathing Accessories > Loofahs', "Mr.Cui'shop", '2 pcs/set LONG Home Sauna Spa Exfoliating Nylon Bath Cloth/Towel - Body Back Scrubber - Magic Shower Washcloth For Body - Shower Scrubber - Remove Dead Skin - Great for Skin Care in the Bath', 'SIZE： 12inch*36inch COLOR：GREEN and BLUE USE: your Neck', ' Men']
# ...

# %% [markdown]
# # Remove punctuation

# %%
import string

def remove_punctuation(text):
    text = "".join([i for i in str(text) if i not in string.punctuation])
    text = text.replace('\u201D', " ")
    text = text.replace('\u2018', " ")
    text = text.replace('\u2019', " ")
    text = text.replace('\u201c', " ")
    text = text.replace('\u2026', " ")
    text = re.sub(r'\.{2,}', ' ', text)

    return text

# %% [markdown]
# # Text reformat

# %%
import re
def text_reformat(text):
    # remove two or more dots
    text = re.sub(r'\.{2,}', ' ', text)
    # remove two or more letters: { bellooooo -> bello}
    text = re.sub(r'(.)\1+', r'\1\1', text)
    # lower text
    return text.lower()

# %% [markdown]
# # Preprocessing call

# %% [markdown]
#  # Stopwords removal

# %%
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import word_tokenize


def remove_stopwords(tokens):
    nltk.download('stopwords')
    stop_words = set(stopwords.words('english'))
    
    return [i for i in tokens if i not in stop_words]

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # Remove meaningless words

# %%
def miningfull_words(stemmed):
    return [word for word in stemmed if len(word) > 2]

# %%
import csv
import os

data = []

with open('filtered.csv', 'r') as csv_file:
  csv_reader = csv.reader(csv_file, delimiter=',')
  line_count = 0
  for row in csv_reader:
    if line_count == 0:
      print(f'Column names are {", ".join(row)}')
      line_count += 1
    else:
      print(row)
      line_count += 1
      data.append(row)

print(data)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import csv

with open('drive/MyDrive/BPM/cleaned_data/prompt_completion.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
      print("prompt:" + row[0])
      print("completion:" + row[1])
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import csv
import re
header = ['prompt', 'completion']
with open('drive/MyDrive/BPM/cleaned_data/filtered.csv', 'r') as csv_file:
  csv_reader = csv.reader(csv_file, delimiter=',')
  line_count = 0
  prompt = []
  completion = []
  csv.field_size_limit(100000000)
  for row in csv_reader:
    if line_count == 0:
      print(f'Column names are {", ".join(row)}')
      line_count += 1
    else:
      if line_count == 1: 
        print(row)
      line_count += 1
      #print(row)
      text = row[3]
      text = text.replace("[", "")
      text = text.replace("]", "")
      text = text.replace("'", "")
      re.sub(' +', ' ', text)
      text = text.split(",")
      if line_count == 2:
        print(text)
      stringa = ""
      # for i in range(len(text)):
      stringa = stringa + " " + text[0] + " "

      if row[5] == "": 
        stringa = stringa + row[4]
        prompt.append(stringa)
      else: 
        stringa = stringa + row[4] + " " + row[5]
        prompt.append(stringa)


      completion.append(row[2])

print(prompt[0])
print(completion[0])
# Out:
# Column names are asin, imUrl, description, categories, title, brand
# ['0132793040', 'http://ecx.images-amazon.com/images/I/31JIPhp%2BGIL.jpg', 'The Kelby Training DVD Mastering Blend Modes in Adobe Photoshop CS5 with Corey Barker is a useful tool for becoming familiar with the use of blend modes in Adobe Photoshop. For those who are serious about mastering all that Photoshop has to offer, mastering blend modes is just as important as mastering layers.In this DVD tutorial, seasoned expert Corey Barker explores the function of blend modes in a variety of scenarios such as image restoration, sharpening, adjustments, special effects and much more. Since every project scenario is different, Corey encourages you to experiment with these blend modes by giving you the skills and confidence you need.', "[['Electronics', 'Computers & Accessories', 'Cables & Accessories', 'Monitor Accessories']]", 'Kelby Training DVD: Mastering Blend Modes in Adobe Photoshop CS5 By Corey Barker', '']
# ...

# %%
import csv

header = ["characteristics", "description"]

with open('drive/MyDrive/BPM/cleaned_data/characteristics_description.csv', 'w') as write_file:
    writer = csv.writer(write_file)

    # write the header
    writer.writerow(header)

    # write the data
    for i in range(len(prompt)):
        row = []
        row.append(prompt[i])
        row.append(completion[i])
        writer.writerow(row)

# %%
openai tools fine_tunes.prepare_data -f prompt_completion.csv
# Out:
#   File "<ipython-input-8-663bcc10e3ab>", line 1
#     openai tools fine_tunes.prepare_data -f prompt_completion.csv
#            ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import numpy as np
import random
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import GPT2Tokenizer, GPT2LMHeadModel, AdamW, get_linear_schedule_with_warmup
from tqdm import tqdm, trange
import torch.nn.functional as F
import csv

tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 23.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 63.0 MB/s eta 0:00:00
# ...
